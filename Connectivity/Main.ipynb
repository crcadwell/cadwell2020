# %%
import datajoint as dj
import schema
import pandas as pd

# %%
dj.ERD(schema)

# %% [markdown]
# # Fill tables

# %%
schema.Connection().fill()

# %%
schema.PPickSister().populate()
schema.ExpectedSisterInput().populate()

# %%
df = pd.DataFrame(schema.ExpectedSisterInput().fetch())
df.to_csv('data/expected_input_2019-06-04.csv')
